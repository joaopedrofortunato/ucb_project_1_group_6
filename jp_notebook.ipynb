# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
wh_2022_path = "main_resources/world_happiness/2022.csv"
wh_2021_path = "main_resources/world_happiness/2021.csv"
wh_2020_path = "main_resources/world_happiness/2020.csv"
wh_2019_path = "main_resources/world_happiness/2019.csv"
wh_2018_path = "main_resources/world_happiness/2018.csv"
wh_2017_path = "main_resources/world_happiness/2017.csv"
wh_2016_path = "main_resources/world_happiness/2016.csv"
wh_2015_path = "main_resources/world_happiness/2015.csv"

# Read the mouse data and the study results
wh_2022_df = pd.read_csv(wh_2022_path)
wh_2021_df = pd.read_csv(wh_2021_path)
wh_2020_df = pd.read_csv(wh_2020_path)
wh_2019_df = pd.read_csv(wh_2019_path)
wh_2018_df = pd.read_csv(wh_2018_path)
wh_2017_df = pd.read_csv(wh_2017_path)
wh_2016_df = pd.read_csv(wh_2016_path)
wh_2015_df = pd.read_csv(wh_2015_path)

# %%
cols = pd.DataFrame([wh_2022_df.columns,
                     wh_2021_df.columns,
                     wh_2020_df.columns,
                     wh_2019_df.columns,
                     wh_2018_df.columns,
                     wh_2017_df.columns,
                     wh_2016_df.columns,
                     wh_2015_df.columns],
                     index=["2022",
                            "2021",
                            "2020",
                            "2019",
                            "2018",
                            "2017",
                            "2016",
                            "2015"])

cols
# Out:
#                 0                   1                2   \
# 2022          RANK             Country  Happiness score
# 2021  Country name  Regional indicator     Ladder score
# 2020  Country name  Regional indicator     Ladder score
# 2019  Overall rank   Country or region            Score
# 2018  Overall rank   Country or region            Score
# 2017       Country      Happiness.Rank  Happiness.Score
# 2016       Country              Region   Happiness Rank
# 2015       Country              Region   Happiness Rank
#
#                                   3                          4   \
# 2022                    Whisker-high                Whisker-low
# 2021  Standard error of ladder score               upperwhisker
# 2020  Standard error of ladder score               upperwhisker
# 2019                  GDP per capita             Social support
# 2018                  GDP per capita             Social support
# 2017                    Whisker.high                Whisker.low
# ...

# %%
wh_2022_df[["RANK","Country","Happiness score","Dystopia (1.83) + residual","Explained by: GDP per capita","Explained by: Social support","Explained by: Healthy life expectancy","Explained by: Freedom to make life choices","Explained by: Generosity",""]]
wh_2021_df
wh_2020_df
wh_2019_df
wh_2018_df
wh_2017_df
wh_2016_df
wh_2015_df

# %%
#wh_2022_df.rename(columns={"Country":"country",
#                           "RANK":"ranking",
#                           "Happiness score":"score",
#                           "Dystopia (1.83) + residual":"dystopia_residual",
#                           "Explained by: GDP per capita":"gdp_per_capita",
#                           "Explained by: Social support":"social_support",
#                           "Explained by: Healthy life expectancy":"life_expectancy",
#                           "Explained by: Freedom to make life choices":"freedom",
#                           "Explained by: Generosity":"generosity",
#                           "Explained by: Perceptions of corruption":"corruption"
#                           })

# merge on "Country"

# drop
# "Whisker-high_2022", "Whisker-low_2022"

# %%
data_frames = [wh_2022_df, wh_2021_df, wh_2020_df, wh_2019_df, wh_2018_df, wh_2017_df, wh_2016_df, wh_2015_df]

for year,df in zip(range(2022,2014,-1),data_frames):

    year = str(year)
    
    for col in df.columns:
        if "country" in col:
            df.rename(columns={col: "country"}, inplace=True)
        else:
            new_col = col + '_' + year
            df.rename(columns={col: new_col}, inplace=True)

# %%
df = pd.merge(
     pd.merge(
     pd.merge(
     pd.merge(
     pd.merge(
     pd.merge(
     pd.merge(wh_2022_df,
              wh_2021_df,on="Country"),
              wh_2020_df,on="Country"),
              wh_2019_df,on="Country"),
              wh_2018_df,on="Country"),
              wh_2017_df,on="Country"),
              wh_2016_df,on="Country"),
              wh_2015_df,on="Country")

# %%
wh_2022_df.head()
# Out:
#    RANK_2022      Country Happiness score_2022 Whisker-high_2022  \
# 0          1      Finland                7,821             7,886
# 1          2      Denmark                7,636             7,710
# 2          3      Iceland                7,557             7,651
# 3          4  Switzerland                7,512             7,586
# 4          5  Netherlands                7,415             7,471
#
#   Whisker-low_2022 Dystopia (1.83) + residual_2022  \
# 0            7,756                           2,518
# 1            7,563                           2,226
# 2            7,464                           2,320
# 3            7,437                           2,153
# 4            7,359                           2,137
#
#   Explained by: GDP per capita_2022 Explained by: Social support_2022  \
# 0                             1,892                             1,258
# 1                             1,953                             1,243
# ...

# %%
#wh_2021_df.rename(columns={"Country":"country",
#                           "Regional indicator":"region",
#                           "Ladder score":"score",
#                           "Dystopia + residual_2021":"dystopia_residual",
#                           "Explained by: Log GDP per capita":"gdp_per_capita",
#                           "Social support":"social_support",
#                           "Healthy life expectancy":"life_expectancy",
#                           "Freedom to make life choices":"freedom",
#                           "Generosity":"generosity",
#                           "Perceptions of corruption":"corruption"
#                           })

# merge on "Country"

# add "ranking"

# drop
# "Standard error of ladder score", "upperwhisker", "lowerwhisker"

# %%
wh_2021_df.head()
# Out:
#        Country Regional indicator_2021  Ladder score_2021  \
# 0      Finland          Western Europe              7.842
# 1      Denmark          Western Europe              7.620
# 2  Switzerland          Western Europe              7.571
# 3      Iceland          Western Europe              7.554
# 4  Netherlands          Western Europe              7.464
#
#    Standard error of ladder score_2021  upperwhisker_2021  lowerwhisker_2021  \
# 0                                0.032              7.904              7.780
# 1                                0.035              7.687              7.552
# 2                                0.036              7.643              7.500
# 3                                0.059              7.670              7.438
# 4                                0.027              7.518              7.410
#
#    Logged GDP per capita_2021  Social support_2021  \
# 0                      10.775                0.954
# ...

# %%
wh_2020_df.head()
# Out:
#        Country Regional indicator_2020  Ladder score_2020  \
# 0      Finland          Western Europe             7.8087
# 1      Denmark          Western Europe             7.6456
# 2  Switzerland          Western Europe             7.5599
# 3      Iceland          Western Europe             7.5045
# 4       Norway          Western Europe             7.4880
#
#    Standard error of ladder score_2020  upperwhisker_2020  lowerwhisker_2020  \
# 0                             0.031156           7.869766           7.747634
# 1                             0.033492           7.711245           7.579955
# 2                             0.035014           7.628528           7.491272
# 3                             0.059616           7.621347           7.387653
# 4                             0.034837           7.556281           7.419719
#
#    Logged GDP per capita_2020  Social support_2020  \
# 0                   10.639267             0.954330
# ...

# %%
wh_2019_df.head()
# Out:
#    Overall rank_2019      Country  Score_2019  GDP per capita_2019  \
# 0                  1      Finland       7.769                1.340
# 1                  2      Denmark       7.600                1.383
# 2                  3       Norway       7.554                1.488
# 3                  4      Iceland       7.494                1.380
# 4                  5  Netherlands       7.488                1.396
#
#    Social support_2019  Healthy life expectancy_2019  \
# 0                1.587                         0.986
# 1                1.573                         0.996
# 2                1.582                         1.028
# 3                1.624                         1.026
# 4                1.522                         0.999
#
#    Freedom to make life choices_2019  Generosity_2019  \
# 0                              0.596            0.153
# 1                              0.592            0.252
# 2                              0.603            0.271
# ...

# %%
wh_2018_df.head()
# Out:
#    Overall rank_2018      Country  Score_2018  GDP per capita_2018  \
# 0                  1      Finland       7.632                1.305
# 1                  2       Norway       7.594                1.456
# 2                  3      Denmark       7.555                1.351
# 3                  4      Iceland       7.495                1.343
# 4                  5  Switzerland       7.487                1.420
#
#    Social support_2018  Healthy life expectancy_2018  \
# 0                1.592                         0.874
# 1                1.582                         0.861
# 2                1.590                         0.868
# 3                1.644                         0.914
# 4                1.549                         0.927
#
#    Freedom to make life choices_2018  Generosity_2018  \
# 0                              0.681            0.202
# 1                              0.686            0.286
# 2                              0.683            0.284
# ...

# %%
wh_2017_df.head()
# Out:
#        Country  Happiness.Rank_2017  Happiness.Score_2017  Whisker.high_2017  \
# 0       Norway                    1                 7.537           7.594445
# 1      Denmark                    2                 7.522           7.581728
# 2      Iceland                    3                 7.504           7.622030
# 3  Switzerland                    4                 7.494           7.561772
# 4      Finland                    5                 7.469           7.527542
#
#    Whisker.low_2017  Economy..GDP.per.Capita._2017  Family_2017  \
# 0          7.479556                       1.616463     1.533524
# 1          7.462272                       1.482383     1.551122
# 2          7.385970                       1.480633     1.610574
# 3          7.426227                       1.564980     1.516912
# 4          7.410458                       1.443572     1.540247
#
#    Health..Life.Expectancy._2017  Freedom_2017  Generosity_2017  \
# ...

# %%
wh_2016_df.head()
# Out:
#        Country     Region_2016  Happiness Rank_2016  Happiness Score_2016  \
# 0      Denmark  Western Europe                    1                 7.526
# 1  Switzerland  Western Europe                    2                 7.509
# 2      Iceland  Western Europe                    3                 7.501
# 3       Norway  Western Europe                    4                 7.498
# 4      Finland  Western Europe                    5                 7.413
#
#    Lower Confidence Interval_2016  Upper Confidence Interval_2016  \
# 0                           7.460                           7.592
# 1                           7.428                           7.590
# 2                           7.333                           7.669
# 3                           7.421                           7.575
# 4                           7.351                           7.475
#
#    Economy (GDP per Capita)_2016  Family_2016  Health (Life Expectancy)_2016  \
# ...

# %%
wh_2015_df.head()
# Out:
#        Country     Region_2015  Happiness Rank_2015  Happiness Score_2015  \
# 0  Switzerland  Western Europe                    1                 7.587
# 1      Iceland  Western Europe                    2                 7.561
# 2      Denmark  Western Europe                    3                 7.527
# 3       Norway  Western Europe                    4                 7.522
# 4       Canada   North America                    5                 7.427
#
#    Standard Error_2015  Economy (GDP per Capita)_2015  Family_2015  \
# 0              0.03411                        1.39651      1.34951
# 1              0.04884                        1.30232      1.40223
# 2              0.03328                        1.32548      1.36058
# 3              0.03880                        1.45900      1.33095
# 4              0.03553                        1.32629      1.32261
#
#    Health (Life Expectancy)_2015  Freedom_2015  \
# 0                        0.94143       0.66557
# ...
